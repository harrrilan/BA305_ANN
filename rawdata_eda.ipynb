# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv('/Users/harrilan/Desktop/school/2024 Fall/BA305/project/tn_nashville_2020_04_01.csv')
# Out:
# /var/folders/m2/b_qd00912hg07bdfxg73hd3h0000gn/T/ipykernel_9369/2214966648.py:1: DtypeWarning: Columns (6,8,15,16,17,22,23,24,25,29,30,31,32,33,35,36,37,38,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('/Users/harrilan/Desktop/school/2024 Fall/BA305/project/tn_nashville_2020_04_01.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3092351 entries, 0 to 3092350
# Data columns (total 42 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   raw_row_number                  object
#  1   date                            object
#  2   time                            object
#  3   location                        object
#  4   lat                             float64
#  5   lng                             float64
#  6   precinct                        object
#  7   reporting_area                  float64
#  8   zone                            object
#  9   subject_age                     float64
#  10  subject_race                    object
#  11  subject_sex                     object
#  12  officer_id_hash                 object
#  13  type                            object
#  14  violation                       object
#  15  arrest_made                     object
#  16  citation_issued                 object
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df.head()
# Out:
#   raw_row_number        date      time  \
# 0         232947  2010-10-10       NaN
# 1         237161  2010-10-10  10:00:00
# 2         232902  2010-10-10  10:00:00
# 3         233219  2010-10-10  22:00:00
# 4         232780  2010-10-10  01:00:00
#
#                                             location        lat        lng  \
# 0  DOMINICAN DR & ROSA L PARKS BLVD, NASHVILLE, T...  36.187925 -86.798519
# 1            1122 LEBANON PIKE, NASHVILLE, TN, 37210  36.155521 -86.735902
# 2                       898 DAVIDSON DR, , TN, 37205  36.117420 -86.895593
# 3  MURFREESBORO PIKE & NASHBORO BLVD, ANTIOCH, TN...  36.086799 -86.648581
# 4                      BUCHANAN ST, NORTH, TN, 37208  36.180038 -86.809109
#
#   precinct  reporting_area   zone  subject_age subject_race subject_sex  \
# 0      6.0          4403.0  611.0         27.0        black        male
# 1      5.0          9035.0  513.0         18.0        white        male
# ...

# %%
df_dropped = df.drop(columns=[
    'age_group', 
    ])
